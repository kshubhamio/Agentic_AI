# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
# Out:
# True

# %%
google_api_key = os.getenv("GOOGLE_API_KEY")
huggingface_api_key = os.getenv("HUGGINGFACE_API_KEY")

google_base_url = os.getenv("GOOGLE_BASE_URL")
huggingface_base_url = os.getenv("HUGGINGFACE_BASE_URL")

# %%
if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google api key not found")
if huggingface_api_key:
    print(f"HuggingFace API Key exists and begins {google_api_key[:2]}")
else:
    print("HuggingFace api key not found")
# Out:
# Google API Key exists and begins AQ
# HuggingFace API Key exists and begins AQ

# %%
gemini = OpenAI(base_url= google_base_url, api_key= google_api_key)
hf =OpenAI(base_url= huggingface_base_url, api_key= huggingface_api_key)

# %%
request = "Please propose a hard, challenging question to assess IQ. Respond only with the question."
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
response = gemini.chat.completions.create(
    model="gemini-3.5-flash",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# Three highly intelligent logicians, A, B, and C, are shown a set of 8 cards: 2 Red, 2 Blue, 2 Green, and 2 Yellow. Two cards are secretly dealt to each logician, and the remaining 2 cards are placed face down in a box. Each logician knows only their own cards. They make the following statements in order:
#
# A: "I do not have two cards of the same color, and I know B does not either."
# B: "With that information, I now know the exact colors of the two cards in the box."
# C: "I still do not know the colors of my own cards, but I now know B is holding at least one Green card."
#
# Assuming all logicians reason perfectly and tell the truth, what are the colors of the two cards in the box?
